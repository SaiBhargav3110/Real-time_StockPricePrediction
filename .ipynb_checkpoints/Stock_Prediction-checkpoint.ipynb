# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
import matplotlib.pyplot as plt
import math

# %%
# Load and preprocess the data
def load_google_stock_data(csv_path):
    data = pd.read_csv(csv_path, skiprows=2)
    data.columns = ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
    data['Date'] = pd.to_datetime(data['Date'])
    data.set_index('Date', inplace=True)
    return data

google_data = load_google_stock_data('/Users/madhuradeshmukh/Desktop/stock_data/Google_last_20_years.csv')

# Extract 'Close' prices and scale the data
dataset = google_data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# Create sliding windows
def create_dataset(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i - window_size:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

window_size = 30
X, y = create_dataset(scaled_data, window_size)

# Split into training and testing sets
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape for LSTM input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compile and train the model
model.compile(optimizer='adam', loss='mean_squared_error')
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# /Users/madhuradeshmukh/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0028 - val_loss: 8.0612e-04
# Epoch 2/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.9386e-04 - val_loss: 0.0019
# Epoch 3/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.5927e-04 - val_loss: 0.0029
# Epoch 4/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.5606e-04 - val_loss: 0.0023
# Epoch 5/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.2258e-04 - val_loss: 6.7011e-04
# Epoch 6/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7898e-04 - val_loss: 0.0013
# Epoch 7/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.4944e-04 - val_loss: 6.2235e-04
# Epoch 8/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7305e-04 - val_loss: 6.1168e-04
# Epoch 9/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5188e-04 - val_loss: 0.0021
# Epoch 10/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5985e-04 - val_loss: 5.9339e-04
# Epoch 11/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.3396e-04 - val_loss: 0.0012
# Epoch 12/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.3017e-04 - val_loss: 5.3460e-04
# Epoch 13/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.2275e-04 - val_loss: 4.9364e-04
# Epoch 14/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1171e-04 - val_loss: 4.8583e-04
# Epoch 15/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1912e-04 - val_loss: 5.6764e-04
# Epoch 16/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1113e-04 - val_loss: 8.3867e-04
# Epoch 17/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1056e-04 - val_loss: 5.9092e-04
# Epoch 18/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.2282e-04 - val_loss: 5.5543e-04
# Epoch 19/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1761e-04 - val_loss: 0.0011
# Epoch 20/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.3424e-04 - val_loss: 4.6900e-04
# Epoch 21/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.2291e-04 - val_loss: 0.0027
# Epoch 22/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5292e-04 - val_loss: 4.0587e-04
# Epoch 23/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.2062e-04 - val_loss: 3.9627e-04
# Epoch 24/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.2085e-04 - val_loss: 4.0131e-04
# Epoch 25/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1507e-04 - val_loss: 3.8046e-04
# Epoch 26/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0856e-04 - val_loss: 0.0016
# Epoch 27/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0715e-04 - val_loss: 3.8100e-04
# Epoch 28/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0946e-04 - val_loss: 4.2753e-04
# Epoch 29/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0842e-04 - val_loss: 8.4439e-04
# Epoch 30/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0352e-04 - val_loss: 9.3587e-04
# Epoch 31/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.4559e-05 - val_loss: 3.8286e-04
# Epoch 32/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1610e-04 - val_loss: 3.4513e-04
# Epoch 33/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.7821e-05 - val_loss: 4.9149e-04
# Epoch 34/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.9819e-05 - val_loss: 4.4066e-04
# Epoch 35/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0433e-04 - val_loss: 5.2225e-04
# Epoch 36/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1290e-04 - val_loss: 9.1406e-04
# Epoch 37/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.8435e-05 - val_loss: 7.8170e-04
# Epoch 38/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.6708e-05 - val_loss: 4.1311e-04
# Epoch 39/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0801e-04 - val_loss: 4.6126e-04
# Epoch 40/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0481e-04 - val_loss: 0.0011
# Epoch 41/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1579e-04 - val_loss: 0.0023
# Epoch 42/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8831e-04 - val_loss: 4.0209e-04
# Epoch 43/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1661e-04 - val_loss: 8.8688e-04
# Epoch 44/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0315e-04 - val_loss: 3.8154e-04
# Epoch 45/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0463e-04 - val_loss: 8.2047e-04
# Epoch 46/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0590e-04 - val_loss: 3.0066e-04
# Epoch 47/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0498e-04 - val_loss: 3.4780e-04
# Epoch 48/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.8054e-05 - val_loss: 3.0540e-04
# Epoch 49/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.7545e-05 - val_loss: 2.8834e-04
# Epoch 50/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0863e-04 - val_loss: 2.9358e-04

# %%
# Predict and inverse transform predictions
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices.reshape(-1, 1))
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate RMSE
rmse = math.sqrt(mean_squared_error(real_prices, predicted_prices))

# Plot actual vs. predicted prices
plt.figure(figsize=(10, 6))
plt.plot(real_prices, label='Actual Price')
plt.plot(predicted_prices, label='Predicted Price')
plt.xlabel('Time')  # Label for x-axis (Time)
plt.ylabel('Stock Price (USD)')  # Label for y-axis (Stock Price)
plt.title('Actual vs. Predicted Stock Prices for Google') 
plt.legend()
plt.show()

print(f"RMSE: {rmse}")

# Forecast next 5 days
last_window = scaled_data[-window_size:]
forecast = []
for _ in range(5):
    next_pred = model.predict(last_window.reshape(1, window_size, 1))
    forecast.append(scaler.inverse_transform(next_pred)[0, 0])
    last_window = np.append(last_window[1:], next_pred)

print("Next 5 days' forecast for GOOGLE:", forecast)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# RMSE: 3.2285472243526594
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Next 5 days' forecast for GOOGLE: [168.88095, 168.77374, 168.54407, 168.24103, 167.89433]

# %%
# Load and preprocess the data
def load_google_stock_data(csv_path):
    data = pd.read_csv(csv_path, skiprows=2)
    data.columns = ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
    data['Date'] = pd.to_datetime(data['Date'])
    data.set_index('Date', inplace=True)
    return data

google_data = load_google_stock_data('/Users/madhuradeshmukh/Desktop/stock_data/Tesla_last_20_years.csv')

# Extract 'Close' prices and scale the data
dataset = google_data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# Create sliding windows
def create_dataset(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i - window_size:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

window_size = 30
X, y = create_dataset(scaled_data, window_size)

# Split into training and testing sets
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape for LSTM input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compile and train the model
model.compile(optimizer='adam', loss='mean_squared_error')
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# /Users/madhuradeshmukh/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0087 - val_loss: 0.0076
# Epoch 2/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.7787e-04 - val_loss: 0.0023
# Epoch 3/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.7960e-04 - val_loss: 0.0022
# Epoch 4/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9032e-04 - val_loss: 0.0023
# Epoch 5/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.4414e-04 - val_loss: 0.0023
# Epoch 6/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.7817e-04 - val_loss: 0.0029
# Epoch 7/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.2313e-04 - val_loss: 0.0028
# Epoch 8/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.9563e-04 - val_loss: 0.0021
# Epoch 9/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.0141e-04 - val_loss: 0.0016
# Epoch 10/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.9723e-04 - val_loss: 0.0015
# Epoch 11/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.7380e-04 - val_loss: 0.0015
# Epoch 12/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.1475e-04 - val_loss: 0.0037
# Epoch 13/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.1944e-04 - val_loss: 0.0020
# Epoch 14/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.6035e-04 - val_loss: 0.0032
# Epoch 15/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.5683e-04 - val_loss: 0.0014
# Epoch 16/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.5752e-04 - val_loss: 0.0019
# Epoch 17/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.1124e-04 - val_loss: 0.0013
# Epoch 18/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.2310e-04 - val_loss: 0.0018
# Epoch 19/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.5444e-04 - val_loss: 0.0011
# Epoch 20/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.4505e-04 - val_loss: 0.0011
# Epoch 21/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.2959e-04 - val_loss: 0.0024
# Epoch 22/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.3800e-04 - val_loss: 0.0010
# Epoch 23/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.9986e-04 - val_loss: 9.8220e-04
# Epoch 24/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.3347e-04 - val_loss: 0.0018
# Epoch 25/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.2009e-04 - val_loss: 0.0011
# Epoch 26/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.2472e-04 - val_loss: 0.0021
# Epoch 27/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.5762e-04 - val_loss: 0.0017
# Epoch 28/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.0049e-04 - val_loss: 0.0018
# Epoch 29/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.8184e-04 - val_loss: 0.0022
# Epoch 30/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.5432e-04 - val_loss: 9.1268e-04
# Epoch 31/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7696e-04 - val_loss: 9.8515e-04
# Epoch 32/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.1206e-04 - val_loss: 0.0011
# Epoch 33/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7508e-04 - val_loss: 0.0018
# Epoch 34/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.7792e-04 - val_loss: 8.4244e-04
# Epoch 35/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.9507e-04 - val_loss: 9.1418e-04
# Epoch 36/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.2438e-04 - val_loss: 0.0010
# Epoch 37/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.5466e-04 - val_loss: 9.1132e-04
# Epoch 38/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5352e-04 - val_loss: 8.6108e-04
# Epoch 39/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.0655e-04 - val_loss: 8.2067e-04
# Epoch 40/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.4242e-04 - val_loss: 9.6647e-04
# Epoch 41/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7813e-04 - val_loss: 9.8561e-04
# Epoch 42/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.7423e-04 - val_loss: 0.0013
# Epoch 43/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7224e-04 - val_loss: 7.8711e-04
# Epoch 44/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.6478e-04 - val_loss: 8.8209e-04
# Epoch 45/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.6850e-04 - val_loss: 7.6875e-04
# Epoch 46/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.8274e-04 - val_loss: 0.0028
# Epoch 47/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.2975e-04 - val_loss: 0.0012
# Epoch 48/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.1115e-04 - val_loss: 8.0614e-04
# Epoch 49/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.2567e-04 - val_loss: 7.4290e-04
# Epoch 50/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.8970e-04 - val_loss: 8.4904e-04

# %%
# Predict and inverse transform predictions
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices.reshape(-1, 1))
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate RMSE
rmse = math.sqrt(mean_squared_error(real_prices, predicted_prices))

# Plot actual vs. predicted prices
plt.figure(figsize=(10, 6))
plt.plot(real_prices, label='Actual Price')
plt.plot(predicted_prices, label='Predicted Price')
plt.xlabel('Time')  # Label for x-axis (Time)
plt.ylabel('Stock Price (USD)')  # Label for y-axis (Stock Price)
plt.title('Actual vs. Predicted Stock Prices for Tesla') 
plt.legend()
plt.show()

print(f"RMSE: {rmse}")

# Forecast next 5 days
last_window = scaled_data[-window_size:]
forecast = []
for _ in range(5):
    next_pred = model.predict(last_window.reshape(1, window_size, 1))
    forecast.append(scaler.inverse_transform(next_pred)[0, 0])
    last_window = np.append(last_window[1:], next_pred)

print("Next 5 days' forecast for TESLA:", forecast)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RMSE: 11.915112950677345
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Next 5 days' forecast for TESLA: [325.90475, 320.5304, 315.00342, 309.63705, 304.5495]

# %%
# Load and preprocess the data
def load_google_stock_data(csv_path):
    data = pd.read_csv(csv_path, skiprows=2)
    data.columns = ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
    data['Date'] = pd.to_datetime(data['Date'])
    data.set_index('Date', inplace=True)
    return data

google_data = load_google_stock_data('/Users/madhuradeshmukh/Desktop/stock_data/AMZN_last_20_years.csv')

# Extract 'Close' prices and scale the data
dataset = google_data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# Create sliding windows
def create_dataset(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i - window_size:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

window_size = 30
X, y = create_dataset(scaled_data, window_size)

# Split into training and testing sets
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape for LSTM input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compile and train the model
model.compile(optimizer='adam', loss='mean_squared_error')
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# /Users/madhuradeshmukh/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 2/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.4846e-04 - val_loss: 0.0016
# Epoch 3/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.1029e-04 - val_loss: 0.0012
# Epoch 4/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9547e-04 - val_loss: 0.0013
# Epoch 5/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.8323e-04 - val_loss: 0.0025
# Epoch 6/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.8285e-04 - val_loss: 9.2051e-04
# Epoch 7/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7249e-04 - val_loss: 0.0011
# Epoch 8/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.3843e-04 - val_loss: 0.0010
# Epoch 9/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.6350e-04 - val_loss: 0.0012
# Epoch 10/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.5874e-04 - val_loss: 8.5047e-04
# Epoch 11/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7847e-04 - val_loss: 0.0033
# Epoch 12/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.6385e-04 - val_loss: 8.5481e-04
# Epoch 13/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.1103e-04 - val_loss: 9.3838e-04
# Epoch 14/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.3801e-04 - val_loss: 7.1242e-04
# Epoch 15/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.9325e-04 - val_loss: 8.0397e-04
# Epoch 16/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.1784e-04 - val_loss: 0.0011
# Epoch 17/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.0718e-04 - val_loss: 0.0051
# Epoch 18/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.1335e-04 - val_loss: 0.0016
# Epoch 19/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.5606e-04 - val_loss: 6.2470e-04
# Epoch 20/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.9637e-04 - val_loss: 6.2427e-04
# Epoch 21/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7360e-04 - val_loss: 6.8298e-04
# Epoch 22/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.6331e-04 - val_loss: 6.0711e-04
# Epoch 23/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.3298e-04 - val_loss: 6.5422e-04
# Epoch 24/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.8828e-04 - val_loss: 6.3782e-04
# Epoch 25/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.5233e-04 - val_loss: 0.0012
# Epoch 26/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.3812e-04 - val_loss: 0.0011
# Epoch 27/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.6660e-04 - val_loss: 5.7222e-04
# Epoch 28/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.9897e-04 - val_loss: 0.0014
# Epoch 29/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.8129e-04 - val_loss: 0.0011
# Epoch 30/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.8636e-04 - val_loss: 6.0980e-04
# Epoch 31/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.1449e-04 - val_loss: 6.2953e-04
# Epoch 32/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.1006e-04 - val_loss: 0.0017
# Epoch 33/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.6379e-04 - val_loss: 6.0305e-04
# Epoch 34/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.5120e-04 - val_loss: 5.5589e-04
# Epoch 35/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.7494e-04 - val_loss: 4.7583e-04
# Epoch 36/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.4896e-04 - val_loss: 0.0029
# Epoch 37/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7819e-04 - val_loss: 0.0010
# Epoch 38/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.8935e-04 - val_loss: 5.5289e-04
# Epoch 39/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.0698e-04 - val_loss: 0.0013
# Epoch 40/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.4080e-04 - val_loss: 0.0016
# Epoch 41/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.4852e-04 - val_loss: 4.5899e-04
# Epoch 42/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.1075e-04 - val_loss: 7.8766e-04
# Epoch 43/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.1502e-04 - val_loss: 6.7493e-04
# Epoch 44/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.0245e-04 - val_loss: 6.0175e-04
# Epoch 45/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.6403e-04 - val_loss: 4.5350e-04
# Epoch 46/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.3293e-04 - val_loss: 5.0934e-04
# Epoch 47/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.0645e-04 - val_loss: 4.5537e-04
# Epoch 48/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.0463e-04 - val_loss: 6.1121e-04
# Epoch 49/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.4075e-04 - val_loss: 4.8705e-04
# Epoch 50/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.0552e-04 - val_loss: 4.8335e-04

# %%
# Predict and inverse transform predictions
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices.reshape(-1, 1))
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate RMSE
rmse = math.sqrt(mean_squared_error(real_prices, predicted_prices))

# Plot actual vs. predicted prices
plt.figure(figsize=(10, 6))
plt.plot(real_prices, label='Actual Price')
plt.plot(predicted_prices, label='Predicted Price')
plt.xlabel('Time')  # Label for x-axis (Time)
plt.ylabel('Stock Price (USD)')  # Label for y-axis (Stock Price)
plt.title('Actual vs. Predicted Stock Prices for Amazon') 
plt.legend()
plt.show()

print(f"RMSE: {rmse}")

# Forecast next 5 days
last_window = scaled_data[-window_size:]
forecast = []
for _ in range(5):
    next_pred = model.predict(last_window.reshape(1, window_size, 1))
    forecast.append(scaler.inverse_transform(next_pred)[0, 0])
    last_window = np.append(last_window[1:], next_pred)

print("Next 5 days' forecast for AMAZON:", forecast)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# RMSE: 4.67836416535479
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Next 5 days' forecast for AMAZON: [204.19008, 204.7486, 205.0748, 205.3158, 205.52495]

# %%
# Load and preprocess the data
def load_google_stock_data(csv_path):
    data = pd.read_csv(csv_path, skiprows=2)
    data.columns = ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
    data['Date'] = pd.to_datetime(data['Date'])
    data.set_index('Date', inplace=True)
    return data

google_data = load_google_stock_data('/Users/madhuradeshmukh/Desktop/stock_data/AAPL_last_20_years.csv')

# Extract 'Close' prices and scale the data
dataset = google_data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# Create sliding windows
def create_dataset(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i - window_size:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

window_size = 30
X, y = create_dataset(scaled_data, window_size)

# Split into training and testing sets
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape for LSTM input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compile and train the model
model.compile(optimizer='adam', loss='mean_squared_error')
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# /Users/madhuradeshmukh/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0031 - val_loss: 8.1115e-04
# Epoch 2/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.3631e-04 - val_loss: 8.1367e-04
# Epoch 3/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.1307e-04 - val_loss: 0.0035
# Epoch 4/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.8122e-04 - val_loss: 9.4701e-04
# Epoch 5/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.9902e-04 - val_loss: 6.1176e-04
# Epoch 6/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6800e-04 - val_loss: 0.0036
# Epoch 7/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4069e-04 - val_loss: 0.0012
# Epoch 8/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6168e-04 - val_loss: 9.7603e-04
# Epoch 9/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4575e-04 - val_loss: 0.0030
# Epoch 10/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5491e-04 - val_loss: 5.0174e-04
# Epoch 11/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.8678e-04 - val_loss: 4.6896e-04
# Epoch 12/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1807e-04 - val_loss: 0.0066
# Epoch 13/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1601e-04 - val_loss: 4.2576e-04
# Epoch 14/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2061e-04 - val_loss: 4.4385e-04
# Epoch 15/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4993e-04 - val_loss: 4.4668e-04
# Epoch 16/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3073e-04 - val_loss: 0.0014
# Epoch 17/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1757e-04 - val_loss: 4.0908e-04
# Epoch 18/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1070e-04 - val_loss: 6.8264e-04
# Epoch 19/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2270e-04 - val_loss: 3.9906e-04
# Epoch 20/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0156e-04 - val_loss: 4.9203e-04
# Epoch 21/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3681e-04 - val_loss: 4.0531e-04
# Epoch 22/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3331e-04 - val_loss: 6.8677e-04
# Epoch 23/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0668e-04 - val_loss: 4.0479e-04
# Epoch 24/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1343e-04 - val_loss: 3.6086e-04
# Epoch 25/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2123e-04 - val_loss: 0.0017
# Epoch 26/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1259e-04 - val_loss: 3.1423e-04
# Epoch 27/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.7252e-05 - val_loss: 3.6111e-04
# Epoch 28/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0560e-04 - val_loss: 3.6632e-04
# Epoch 29/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1908e-04 - val_loss: 3.4052e-04
# Epoch 30/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1745e-04 - val_loss: 0.0018
# Epoch 31/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0866e-04 - val_loss: 4.3060e-04
# Epoch 32/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5959e-04 - val_loss: 3.5990e-04
# Epoch 33/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1784e-04 - val_loss: 7.0930e-04
# Epoch 34/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.9217e-05 - val_loss: 5.1376e-04
# Epoch 35/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1058e-04 - val_loss: 6.8042e-04
# Epoch 36/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.8851e-05 - val_loss: 5.7179e-04
# Epoch 37/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0056e-04 - val_loss: 0.0017
# Epoch 38/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1168e-04 - val_loss: 5.7424e-04
# Epoch 39/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2905e-04 - val_loss: 8.0294e-04
# Epoch 40/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3208e-05 - val_loss: 2.8407e-04
# Epoch 41/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3758e-05 - val_loss: 0.0039
# Epoch 42/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1635e-04 - val_loss: 3.3215e-04
# Epoch 43/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.0814e-05 - val_loss: 0.0016
# Epoch 44/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1634e-04 - val_loss: 7.6192e-04
# Epoch 45/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1891e-04 - val_loss: 0.0012
# Epoch 46/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5667e-04 - val_loss: 2.9464e-04
# Epoch 47/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3293e-04 - val_loss: 2.8025e-04
# Epoch 48/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0904e-04 - val_loss: 5.1197e-04
# Epoch 49/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0353e-04 - val_loss: 0.0029
# Epoch 50/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4992e-04 - val_loss: 2.6122e-04

# %%
# Predict and inverse transform predictions
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices.reshape(-1, 1))
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate RMSE
rmse = math.sqrt(mean_squared_error(real_prices, predicted_prices))

# Plot actual vs. predicted prices
plt.figure(figsize=(10, 6))
plt.plot(real_prices, label='Actual Price')
plt.plot(predicted_prices, label='Predicted Price')
plt.xlabel('Time')  # Label for x-axis (Time)
plt.ylabel('Stock Price (USD)')  # Label for y-axis (Stock Price)
plt.title('Actual vs. Predicted Stock Prices for Apple') 
plt.legend()
plt.show()

print(f"RMSE: {rmse}")

# Forecast next 5 days
last_window = scaled_data[-window_size:]
forecast = []
for _ in range(5):
    next_pred = model.predict(last_window.reshape(1, window_size, 1))
    forecast.append(scaler.inverse_transform(next_pred)[0, 0])
    last_window = np.append(last_window[1:], next_pred)

print("Next 5 days' forecast for APPLE:", forecast)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# RMSE: 3.8040021468573233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Next 5 days' forecast for APPLE: [232.53705, 232.71722, 232.54416, 232.23698, 231.88846]

# %%
# Load and preprocess the data
def load_google_stock_data(csv_path):
    data = pd.read_csv(csv_path, skiprows=2)
    data.columns = ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
    data['Date'] = pd.to_datetime(data['Date'])
    data.set_index('Date', inplace=True)
    return data

google_data = load_google_stock_data('/Users/madhuradeshmukh/Desktop/stock_data/Microsoft_last_20_years.csv')

# Extract 'Close' prices and scale the data
dataset = google_data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# Create sliding windows
def create_dataset(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i - window_size:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

window_size = 30
X, y = create_dataset(scaled_data, window_size)

# Split into training and testing sets
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape for LSTM input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compile and train the model
model.compile(optimizer='adam', loss='mean_squared_error')
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# /Users/madhuradeshmukh/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 2/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.2101e-04 - val_loss: 0.0019
# Epoch 3/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.0359e-04 - val_loss: 9.2951e-04
# Epoch 4/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.0546e-04 - val_loss: 8.3948e-04
# Epoch 5/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5586e-04 - val_loss: 0.0059
# Epoch 6/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5292e-04 - val_loss: 5.8377e-04
# Epoch 7/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5473e-04 - val_loss: 0.0015
# Epoch 8/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.4380e-04 - val_loss: 5.1821e-04
# Epoch 9/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5851e-04 - val_loss: 6.2100e-04
# Epoch 10/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.4108e-04 - val_loss: 6.0126e-04
# Epoch 11/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.3988e-04 - val_loss: 5.5745e-04
# Epoch 12/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.2823e-04 - val_loss: 5.4464e-04
# Epoch 13/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0861e-04 - val_loss: 4.2732e-04
# Epoch 14/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1429e-04 - val_loss: 0.0012
# Epoch 15/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.6466e-05 - val_loss: 6.8375e-04
# Epoch 16/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2216e-04 - val_loss: 7.2364e-04
# Epoch 17/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.9742e-05 - val_loss: 0.0023
# Epoch 18/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2071e-04 - val_loss: 0.0015
# Epoch 19/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0585e-04 - val_loss: 5.1470e-04
# Epoch 20/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.5680e-05 - val_loss: 3.8074e-04
# Epoch 21/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2151e-04 - val_loss: 4.2710e-04
# Epoch 22/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3359e-04 - val_loss: 0.0013
# Epoch 23/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3386e-04 - val_loss: 0.0023
# Epoch 24/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2378e-04 - val_loss: 4.2832e-04
# Epoch 25/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.6628e-05 - val_loss: 4.4462e-04
# Epoch 26/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5729e-04 - val_loss: 7.0507e-04
# Epoch 27/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4252e-05 - val_loss: 3.1387e-04
# Epoch 28/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0175e-04 - val_loss: 0.0026
# Epoch 29/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0360e-04 - val_loss: 0.0033
# Epoch 30/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0482e-04 - val_loss: 0.0011
# Epoch 31/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.2606e-05 - val_loss: 6.2193e-04
# Epoch 32/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.5334e-05 - val_loss: 0.0023
# Epoch 33/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.7550e-05 - val_loss: 5.9461e-04
# Epoch 34/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.9532e-05 - val_loss: 5.6563e-04
# Epoch 35/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0255e-04 - val_loss: 5.6664e-04
# Epoch 36/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0965e-04 - val_loss: 2.7006e-04
# Epoch 37/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.0375e-05 - val_loss: 4.9063e-04
# Epoch 38/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0772e-04 - val_loss: 5.1434e-04
# Epoch 39/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.8109e-05 - val_loss: 5.1049e-04
# Epoch 40/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.3041e-05 - val_loss: 0.0015
# Epoch 41/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.7032e-05 - val_loss: 4.2206e-04
# Epoch 42/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4853e-05 - val_loss: 0.0024
# Epoch 43/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2538e-04 - val_loss: 0.0014
# Epoch 44/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.5992e-05 - val_loss: 0.0011
# Epoch 45/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.0243e-05 - val_loss: 5.9117e-04
# Epoch 46/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.9094e-05 - val_loss: 5.6848e-04
# Epoch 47/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.0108e-05 - val_loss: 0.0015
# Epoch 48/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.7666e-05 - val_loss: 6.1312e-04
# Epoch 49/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4597e-05 - val_loss: 2.8853e-04
# Epoch 50/50
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0526e-04 - val_loss: 4.9771e-04

# %%
# Predict and inverse transform predictions
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices.reshape(-1, 1))
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate RMSE
rmse = math.sqrt(mean_squared_error(real_prices, predicted_prices))

# Plot actual vs. predicted prices
plt.figure(figsize=(10, 6))
plt.plot(real_prices, label='Actual Price')
plt.plot(predicted_prices, label='Predicted Price')
plt.xlabel('Time')  # Label for x-axis (Time)
plt.ylabel('Stock Price (USD)')  # Label for y-axis (Stock Price)
plt.title('Actual vs. Predicted Stock Prices for Microsoft') 
plt.legend()
plt.show()

print(f"RMSE: {rmse}")

# Forecast next 5 days
last_window = scaled_data[-window_size:]
forecast = []
for _ in range(5):
    next_pred = model.predict(last_window.reshape(1, window_size, 1))
    forecast.append(scaler.inverse_transform(next_pred)[0, 0])
    last_window = np.append(last_window[1:], next_pred)

print("Next 5 days' forecast for MICROSOFT:", forecast)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# RMSE: 10.092982812395679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Next 5 days' forecast for MICROSOFT: [407.16757, 405.24542, 402.34653, 399.11746, 395.8588]
